# %% [markdown]
# <table align="left">
#   <td>
#     <a target="_blank" href="https://colab.research.google.com/github/polyhedron-gdl/unibo-intensive-program-2023/blob/main/2022/1-notebooks/chapter-1-0.ipynb">
#         <img src="https://www.tensorflow.org/images/colab_logo_32px.png" />Run in Google Colab</a>
#   </td>
# </table>

# %% [markdown]
# # Your first ML Model

# %% [markdown]
# ## Import Libraries

# %%
import keras
import numpy as np

# %% [markdown]
# ## Build the Model

# %%
model = keras.Sequential([keras.layers.Dense(units=1, input_shape=[1])])

# %% [markdown]
# When you compile the model, there are two functions:
#
# - the loss and...
# - the optimizer.
#
# **These are the key to machine learning**.
#
# How machine learning works is that the model will make a guess about the relationship between the numbers.
# For example, it might guess that $Y = 5X + 5$. And when training, it will then calculate how good or how bad that guess is, using the loss function.
#
# And then, it will use the optimizer function to generate another guess. The logic is that the combination of these two functions will slowly get us closer and closer to the correct formula.

# %%
model.compile(optimizer='sgd', loss='mean_squared_error')

# %%
xs = np.array([-1.0,  0.0, 1.0, 2.0, 3.0, 4.0], dtype=float)

# %%
ys = np.array([-3.0, -1.0, 1.0, 3.0, 5.0, 7.0], dtype=float)

# %% [markdown]
# ## Train the Model

# %% [markdown]
# In this case, it will go through that loop 500 times,
# making a guess, calculating how accurate that guess is,
# and then using the optimizer to enhance that guess, and so on.
#
# The data itself is set up as an array of Xs and Ys,
# and our process of matching them to each other
# is in the fit method of the model.
#
# We literally say, "*fit the Xs to the Ys and try this 500 times*."
# When it's done, we'll have a ***trained model***.

# %%
model.fit(xs, ys, epochs=500)
# Out:
# Epoch 1/500
# 1/1 [==============================] - 0s 7ms/step - loss: 5.7528e-05
# Epoch 2/500
# 1/1 [==============================] - 0s 8ms/step - loss: 5.6346e-05
# Epoch 3/500
# 1/1 [==============================] - 0s 8ms/step - loss: 5.5190e-05
# Epoch 4/500
# 1/1 [==============================] - 0s 9ms/step - loss: 5.4055e-05
# Epoch 5/500
# 1/1 [==============================] - 0s 6ms/step - loss: 5.2946e-05
# Epoch 6/500
# 1/1 [==============================] - 0s 6ms/step - loss: 5.1858e-05
# Epoch 7/500
# 1/1 [==============================] - 0s 8ms/step - loss: 5.0793e-05
# Epoch 8/500
# 1/1 [==============================] - 0s 5ms/step - loss: 4.9750e-05
# Epoch 9/500
# 1/1 [==============================] - 0s 7ms/step - loss: 4.8728e-05
# Epoch 10/500
# 1/1 [==============================] - 0s 5ms/step - loss: 4.7726e-05
# Epoch 11/500
# 1/1 [==============================] - 0s 5ms/step - loss: 4.6746e-05
# Epoch 12/500
# ...

# %% [markdown]
# ## Use the Model to Predict

# %% [markdown]
# So now you can try to ***predict*** a Y value for a given X.
# What do you think would happen if you tried this line of code
# predict the Y when X equals 10?
# You might think that the answer is 19, right?

# %%
print(model.predict([10.0]))
# Out:
# [[18.999876]]

# %% [markdown]
# But it isn't.
# It's actually something like 18.9.
# It's close to 19, but it's not quite there.
# Why do you think that would be?
# Well, the computer was trained to match only six pairs of numbers.
# It looks like a straight-line relationship between them, for those six,
# but it may not be a straight line for values outside of those six.
# There's a very high probability that it's a straight line,
# but we can't be certain.

# %% [markdown]
# ## Conclusion
#
# Regardless of your experience, you've covered most of the machine learning concepts you'll use in much more complex scenarios. You learned ***how to train a machine learning model*** to find the relationship between two sets of numbers by defining a neural network which you then filled in with a ***loss function*** and an ***optimizer***.
#
# The collection of a network, loss function, and optimization tool handles the process of guessing the ratio of numbers, measuring performance, and then generating new metrics for new hypotheses.
